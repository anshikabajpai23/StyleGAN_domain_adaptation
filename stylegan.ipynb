# %%
# !python -u dess_pd_stylegan3d.py \
  --mode train \
  --dess_dir /Users/anshikabajpai/Desktop/github/RegGAN_domain_adaptation/data/skm-tea-data/nifti \
  --pd_dir /Users/anshikabajpai/Desktop/github/RegGAN_domain_adaptation/data/iu-dataset/nifti \
  --out_dir runs/sanity_3d_stylegan \
  --patch_size 64,64,16 \
  --batch_size 1 \
  --max_iterations 3000 \
  --num_workers 4 \
  --preview_every 200 \
  --save_every 1000
# Out:
# Found DESS scans: 21
# Found PD scans:   22
# Device: cpu
# Patch size: (64, 64, 16), batch size: 1
# /Users/anshikabajpai/Desktop/github/RegGAN_domain_adaptation/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# iter 000000 | D 1.3894 | g 119.4264 | adv 0.6844 | style 0.0024 | content 0.7519 | edge 3.1560 | lap 0.4221 | id 0.4801 | div -0.0008
# iter 000050 | D 0.6957 | g 84.9469 | adv 2.8790 | style 0.0017 | content 0.9519 | edge 1.7016 | lap 0.4759 | id 0.7220 | div -0.0007
# iter 000100 | D 0.0215 | g 79.9449 | adv 4.6445 | style 0.0082 | content 1.0135 | edge 1.4620 | lap 0.4883 | id 0.6278 | div -0.0004
# iter 000150 | D 0.2309 | g 87.9210 | adv 2.6321 | style 0.0146 | content 1.0026 | edge 1.7396 | lap 0.5436 | id 0.7598 | div -0.0016
# ...

# %%
python preprocess.py \
  --dess_root ../data/skm-tea-dataset/nifti \
  --pd_root   ../data/iu-dataset/pd-files
